# %%
import pandas as pd

# %%
df = pd.read_csv("laptopPrice.csv")
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 0          No       No  34649  2 stars                  3                  0
# 1          No       No  38999  3 stars                 65                  5
# 2          No       No  39999  3 stars                  8                  1
# 3          No       No  69990  3 stars                  0                  0
# 4          No       No  26990  3 stars                  0                  0

# %%
df.info
# Out:
# <bound method DataFrame.info of       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]>

# %%
df.duplicated().sum()
# Out:
# 21

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
x = df.drop('Price' , axis=1)
y = df[['Price']]

# %%
x
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   rating  Number of Ratings  \
# 0    No warranty          No       No  2 stars                  3
# 1    No warranty          No       No  3 stars                 65
# 2    No warranty          No       No  3 stars                  8
# 3    No warranty          No       No  3 stars                  0
# 4    No warranty          No       No  3 stars                  0
# ..           ...         ...      ...      ...                ...
# 818       1 year          No       No  3 stars                  0
# 819       1 year          No       No  3 stars                  0
# 820       1 year          No       No  3 stars                  0
# 821       1 year          No       No  3 stars                  0
# 822  No warranty          No       No  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 18 columns]

# %%
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [823 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 787  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 516  Lenovo           Intel        Core i7            10th  16 GB     DDR4
# 64     acer           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 151    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 227  Lenovo           Intel        Core i5            10th   8 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 553     MSI           Intel        Core i7            12th  16 GB     DDR4
# 418    DELL           Intel        Core i5            11th   8 GB     DDR4
# 41   Lenovo           Intel        Core i3            11th   8 GB     DDR4
# 199    ASUS           Intel        Core i5            10th   8 GB   LPDDR4
# 396  Lenovo           Intel        Core i5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 787  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 516   512 GB     0 GB  Windows  64-bit            0 GB  ThinNlight
# 64      0 GB   512 GB  Windows  32-bit            0 GB      Casual
# 151     0 GB  1024 GB  Windows  32-bit            0 GB  ThinNlight
# 227   512 GB     0 GB  Windows  64-bit            0 GB  ThinNlight
# ..       ...      ...      ...     ...             ...         ...
# 553  1024 GB     0 GB  Windows  64-bit            6 GB      Casual
# 418     0 GB  1024 GB  Windows  64-bit            0 GB  ThinNlight
# 41    256 GB     0 GB  Windows  64-bit            0 GB      Casual
# 199     0 GB   512 GB      DOS  32-bit            4 GB      Casual
# 396   512 GB     0 GB  Windows  64-bit            2 GB      Casual
#
#         warranty Touchscreen msoffice   rating  Number of Ratings  \
# 787       1 year          No      Yes  3 stars                  0
# 516      3 years          No       No  3 stars                  0
# 64   No warranty          No       No  3 stars                 61
# 151  No warranty          No       No  3 stars                 43
# 227       1 year          No       No  3 stars                  0
# ..           ...         ...      ...      ...                ...
# 553  No warranty          No       No  4 stars                  4
# 418       1 year          No      Yes  3 stars                470
# 41        1 year         Yes      Yes  4 stars                299
# 199  No warranty          No       No  4 stars               1881
# 396       1 year         Yes      Yes  4 stars                  3
#
#      Number of Reviews
# 787                  0
# 516                  0
# 64                   4
# 151                  7
# 227                  0
# ..                 ...
# 553                  2
# 418                 46
# 41                  41
# 199                241
# 396                  0
#
# [740 rows x 18 columns]

# %%
x_test
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 753  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 420    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 369      HP           Intel        Core i5            11th   8 GB  LPDDR4X
# 318  Lenovo           Intel        Core i5            11th   8 GB     DDR4
# 203      HP           Intel        Core i5            10th   8 GB   LPDDR4
# ..      ...             ...            ...             ...    ...      ...
# 807      HP             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 633    ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 601   APPLE              M1             M1            10th  16 GB     DDR4
# 202      HP           Intel        Core i5            10th   8 GB   LPDDR4
# 179    DELL           Intel        Core i3            10th   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 753   512 GB     0 GB  Windows  64-bit            0 GB      Casual
# 420     0 GB  1024 GB  Windows  64-bit            0 GB  ThinNlight
# 369   512 GB     0 GB  Windows  64-bit            0 GB      Casual
# 318   512 GB     0 GB  Windows  64-bit            0 GB      Casual
# 203     0 GB   512 GB      DOS  32-bit            4 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 807  1024 GB     0 GB  Windows  64-bit            8 GB      Casual
# 633     0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 601   256 GB     0 GB      Mac  64-bit            0 GB      Casual
# 202     0 GB   512 GB      DOS  32-bit            0 GB  ThinNlight
# 179   256 GB  1024 GB  Windows  64-bit            0 GB      Casual
#
#         warranty Touchscreen msoffice   rating  Number of Ratings  \
# 753       1 year          No      Yes  4 stars                530
# 420       1 year          No       No  4 stars               1444
# 369       1 year         Yes       No  3 stars                  0
# 318       1 year          No      Yes  4 stars                125
# 203  No warranty          No       No  3 stars                  0
# ..           ...         ...      ...      ...                ...
# 807       1 year          No      Yes  3 stars                  0
# 633       1 year          No       No  3 stars               4741
# 601       1 year          No       No  4 stars                 45
# 202  No warranty          No       No  4 stars                818
# 179       1 year          No       No  4 stars                  9
#
#      Number of Reviews
# 753                 69
# 420                179
# 369                  0
# 318                 11
# 203                  0
# ..                 ...
# 807                  0
# 633                658
# 601                  4
# 202                109
# 179                  0
#
# [83 rows x 18 columns]

# %%
y_train
# Out:
#       Price
# 787   77988
# 516  174527
# 64    23990
# 151   33990
# 227   49990
# ..      ...
# 553  139990
# 418   48990
# 41    53990
# 199  106167
# 396   86999
#
# [740 rows x 1 columns]

# %%
y_test
# Out:
#       Price
# 753   60990
# 420   46990
# 369  129999
# 318   64990
# 203  102551
# ..      ...
# 807  141990
# 633   25990
# 601  104990
# 202   55990
# 179   44690
#
# [83 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17632\3557823984.py in ?()
# ----> 1 lr.fit(x_train,y_train)
#
# c:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     574         n_jobs_ = self.n_jobs
#     575
#     576         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     577
# --> 578         X, y = self._validate_data(
#     579             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     580         )
#     581
#
# c:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1259         raise ValueError(
#    1260             f"{estimator_name} requires y to be passed, but the target y is None"
#    1261         )
#    1262
# -> 1263     X = check_array(
#    1264         X,
#    1265         accept_sparse=accept_sparse,
#    1266         accept_large_sparse=accept_large_sparse,
#
# c:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     994                         )
#     995                     array = xp.astype(array, dtype, copy=False)
#     996                 else:
#     997                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 998             except ComplexWarning as complex_warning:
#     999                 raise ValueError(
#    1000                     "Complex data not supported\n{}\n".format(array)
#    1001                 ) from complex_warning
#
# c:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# c:\Users\Piyush\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Lenovo'
